# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('accidents_2012_to_2014.csv')

# %%
data.head()
# Out:
#   Accident_Index  Location_Easting_OSGR  Location_Northing_OSGR  Longitude  \
# 0  201201BS70001                 527200                  178760  -0.169101
# 1  201201BS70002                 524930                  181430  -0.200838
# 2  201201BS70003                 525860                  178080  -0.188636
# 3  201201BS70004                 524980                  181030  -0.200259
# 4  201201BS70005                 526170                  179200  -0.183773
#
#     Latitude  Police_Force  Accident_Severity  Number_of_Vehicles  \
# 0  51.493429             1                  3                   2
# 1  51.517931             1                  3                   2
# 2  51.487618             1                  3                   2
# 3  51.514325             1                  3                   1
# 4  51.497614             1                  3                   1
#
#    Number_of_Casualties        Date  ...   \
# 0                     1  19/01/2012  ...
# ...

# %%
data.Weather_Conditions.unique()
# Out:
# array(['Fine without high winds', 'Raining without high winds', 'Other',
#        'Snowing without high winds', 'Raining with high winds',
#        'Fine with high winds', 'Unknown', 'Fog or mist',
#        'Snowing with high winds'], dtype=object)

# %%
data.Light_Conditions.unique()
# Out:
# array(['Darkness: Street lights present and lit',
#        'Daylight: Street light present', 'Darkeness: No street lighting',
#        'Darkness: Street lights present but unlit',
#        'Darkness: Street lighting unknown'], dtype=object)

# %%
data.Road_Surface_Conditions.unique()
# Out:
# array(['Dry', 'Wet/Damp', 'Frost/Ice', 'Snow',
#        'Flood (Over 3cm of water)', nan], dtype=object)

# %%
data.Pedestrian_Human_Control.unique()
# Out:
# array(['None within 50 metres', 'Control by other authorised person',
#        'Control by school crossing patrol'], dtype=object)

# %%
##drop unnecessary columns
data1 = data.drop(columns=['Location_Easting_OSGR','Location_Northing_OSGR','Longitude','Latitude','Police_Force','Local_Authority_(District)','Local_Authority_(Highway)','1st_Road_Class','1st_Road_Number','Junction_Detail','2nd_Road_Class','2nd_Road_Number','Urban_or_Rural_Area','LSOA_of_Accident_Location'])

# %%
data1.head()
# Out:
#   Accident_Index  Accident_Severity  Number_of_Vehicles  Number_of_Casualties  \
# 0  201201BS70001                  3                   2                     1
# 1  201201BS70002                  3                   2                     1
# 2  201201BS70003                  3                   2                     1
# 3  201201BS70004                  3                   1                     1
# 4  201201BS70005                  3                   1                     1
#
#          Date  Day_of_Week   Time           Road_Type  Speed_limit  \
# 0  19/01/2012            5  20:35  Single carriageway           30
# 1    4/1/2012            4  17:00  Single carriageway           30
# 2   10/1/2012            3  10:07      One way street           30
# 3  18/01/2012            4  12:20  Single carriageway           30
# 4  17/01/2012            3  20:24  Single carriageway           30
#
#            Junction_Control Pedestrian_Human_Control  \
# ...

# %%
##check for null values
data1.isna().sum()
# Out:
# Accident_Index                                      0
# Accident_Severity                                   0
# Number_of_Vehicles                                  0
# Number_of_Casualties                                0
# Date                                                0
# Day_of_Week                                         0
# Time                                               13
# Road_Type                                           0
# Speed_limit                                         0
# Junction_Control                               178610
# Pedestrian_Human_Control                            0
# Pedestrian_Physical_Facilities                      0
# Light_Conditions                                    0
# Weather_Conditions                                  0
# Road_Surface_Conditions                           755
# Special_Conditions_at_Site                          2
# Carriageway_Hazards                                 3
# ...

# %%
data.Junction_Control.unique()
# Out:
# array(['Automatic traffic signal', 'Giveway or uncontrolled', nan,
#        'Authorised person', 'Stop Sign'], dtype=object)

# %%
data2 = data1.drop(columns=['Junction_Control'])

# %%
data2.dropna(subset=['Time','Road_Surface_Conditions','Special_Conditions_at_Site','Carriageway_Hazards','Did_Police_Officer_Attend_Scene_of_Accident'])
# Out:
#        Accident_Index  Accident_Severity  Number_of_Vehicles  \
# 0       201201BS70001                  3                   2
# 1       201201BS70002                  3                   2
# 2       201201BS70003                  3                   2
# 3       201201BS70004                  3                   1
# 4       201201BS70005                  3                   1
# 5       201201BS70006                  3                   2
# 6       201201BS70007                  3                   1
# 7       201201BS70008                  3                   2
# 8       201201BS70010                  3                   2
# 9       201201BS70011                  3                   2
# 10      201201BS70012                  3                   1
# 11      201201BS70013                  3                   2
# 12      201201BS70014                  3                   2
# 13      201201BS70015                  3                   1
# ...

# %%
data2.isna().sum()
# Out:
# Accident_Index                                   0
# Accident_Severity                                0
# Number_of_Vehicles                               0
# Number_of_Casualties                             0
# Date                                             0
# Day_of_Week                                      0
# Time                                            13
# Road_Type                                        0
# Speed_limit                                      0
# Pedestrian_Human_Control                         0
# Pedestrian_Physical_Facilities                   0
# Light_Conditions                                 0
# Weather_Conditions                               0
# Road_Surface_Conditions                        755
# Special_Conditions_at_Site                       2
# Carriageway_Hazards                              3
# Did_Police_Officer_Attend_Scene_of_Accident      2
# Year                                             0
# dtype: int64

# %%
data3 = data2.dropna(axis=1, how='any')

# %%
data3.isna().sum()
# Out:
# Accident_Index                    0
# Accident_Severity                 0
# Number_of_Vehicles                0
# Number_of_Casualties              0
# Date                              0
# Day_of_Week                       0
# Road_Type                         0
# Speed_limit                       0
# Pedestrian_Human_Control          0
# Pedestrian_Physical_Facilities    0
# Light_Conditions                  0
# Weather_Conditions                0
# Year                              0
# dtype: int64

# %%
data3.head()
# Out:
#   Accident_Index  Accident_Severity  Number_of_Vehicles  Number_of_Casualties  \
# 0  201201BS70001                  3                   2                     1
# 1  201201BS70002                  3                   2                     1
# 2  201201BS70003                  3                   2                     1
# 3  201201BS70004                  3                   1                     1
# 4  201201BS70005                  3                   1                     1
#
#          Date  Day_of_Week           Road_Type  Speed_limit  \
# 0  19/01/2012            5  Single carriageway           30
# 1    4/1/2012            4  Single carriageway           30
# 2   10/1/2012            3      One way street           30
# 3  18/01/2012            4  Single carriageway           30
# 4  17/01/2012            3  Single carriageway           30
#
#   Pedestrian_Human_Control               Pedestrian_Physical_Facilities  \
# ...

# %%
data3.groupby('Road_Type').mean()
##One way streets don't have many vehicles and are slow
# Out:
#                     Accident_Severity  Number_of_Vehicles  \
# Road_Type
# Dual carriageway             2.847859            2.021470
# One way street               2.850231            1.584637
# Roundabout                   2.897369            1.905689
# Single carriageway           2.823579            1.790351
# Slip road                    2.889579            1.956909
# Unknown                      2.870679            1.594160
#
#                     Number_of_Casualties  Day_of_Week  Speed_limit  \
# Road_Type
# Dual carriageway                1.482924     4.083563    51.369435
# One way street                  1.179414     4.212365    29.766365
# Roundabout                      1.246829     4.069729    37.623069
# Single carriageway              1.317843     4.114955    35.839729
# Slip road                       1.420551     4.055521    53.697949
# Unknown                         1.216925     4.131108    34.547080
#
#                            Year
# Road_Type
# ...

# %%
data2.groupby('Day_of_Week').mean()
##looks like Day 1 is Sunday as day 1 and day 7 seem to be similar
# Out:
#              Accident_Severity  Number_of_Vehicles  Number_of_Casualties  \
# Day_of_Week
# 1                     2.798386            1.775266              1.423028
# 2                     2.842413            1.831428              1.311862
# 3                     2.842212            1.845355              1.302605
# 4                     2.844949            1.845207              1.301067
# 5                     2.841190            1.847928              1.311251
# 6                     2.838654            1.847135              1.330397
# 7                     2.813874            1.781614              1.392904
#
#              Speed_limit         Year
# Day_of_Week
# 1              39.676765  2012.929031
# 2              38.200075  2012.929442
# 3              37.873741  2012.937098
# 4              37.875421  2012.929061
# 5              37.861390  2012.916511
# 6              38.160649  2012.933074
# 7              38.398527  2012.921899

# %%
data3.groupby('Speed_limit').mean()
##Shows that as the speed limit increases we tend to see more vehicles involved and more casualties
# Out:
#              Accident_Severity  Number_of_Vehicles  Number_of_Casualties  \
# Speed_limit
# 10                    3.000000            1.000000              1.000000
# 20                    2.839647            1.641303              1.179901
# 30                    2.855161            1.786752              1.256270
# 40                    2.826363            1.958602              1.434333
# 50                    2.802218            2.003235              1.508722
# 60                    2.740665            1.786954              1.501202
# 70                    2.837219            2.114344              1.579088
#
#                     Year
# Speed_limit
# 10           2012.000000
# 20           2013.049144
# 30           2012.916780
# 40           2012.946348
# 50           2012.978165
# 60           2012.931079
# 70           2012.948132

# %%
##data3["Day_of_Week"]= data3["Day_of_Week"].replace(2, "Monday") 
##data3["Day_of_Week"]= data3["Day_of_Week"].replace(3, "Tuesday") 
##data3["Day_of_Week"]= data3["Day_of_Week"].replace(4, "Wednesday") 
##data3["Day_of_Week"]= data3["Day_of_Week"].replace(5, "Thursday") 
##data3["Day_of_Week"]= data3["Day_of_Week"].replace(6, "Friday") 
##data3["Day_of_Week"]= data3["Day_of_Week"].replace(7, "Saturday") 
##data3["Day_of_Week"]= data3["Day_of_Week"].replace(7, "Saturday") 
data3["Speed_limit"]= data3["Speed_limit"].replace(10, "Ten") 
data3["Speed_limit"]= data3["Speed_limit"].replace(20, "Twenty")
data3["Speed_limit"]= data3["Speed_limit"].replace(30, "Thirty") 
data3["Speed_limit"]= data3["Speed_limit"].replace(40, "Fourty") 
data3["Speed_limit"]= data3["Speed_limit"].replace(50, "Fifty") 
data3["Speed_limit"]= data3["Speed_limit"].replace(60, "Sixty") 
data3["Speed_limit"]= data3["Speed_limit"].replace(70, "Seventy") 
data3.head()
# Out:
# C:\Users\lakec\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\lakec\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# C:\Users\lakec\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
dummyday = pd.get_dummies(data3['Day_of_Week'])
dummyroad = pd.get_dummies(data3['Road_Type'])
dummyspeed = pd.get_dummies(data3['Speed_limit'])
dummyphc = pd.get_dummies(data3['Pedestrian_Human_Control'])
dummyppf = pd.get_dummies(data3['Pedestrian_Physical_Facilities'])
dummylight = pd.get_dummies(data3['Light_Conditions'])
dummyweather = pd.get_dummies(data3['Weather_Conditions'])

# %%
data4 = pd.concat([data3, dummyday, dummyroad, dummyspeed, dummyphc, dummyppf, dummylight, dummyweather], axis=1)
data4.head()
# Out:
#   Accident_Index  Accident_Severity  Number_of_Vehicles  Number_of_Casualties  \
# 0  201201BS70001                  3                   2                     1
# 1  201201BS70002                  3                   2                     1
# 2  201201BS70003                  3                   2                     1
# 3  201201BS70004                  3                   1                     1
# 4  201201BS70005                  3                   1                     1
#
#          Date Day_of_Week           Road_Type Speed_limit  \
# 0  19/01/2012    Thursday  Single carriageway      Thirty
# 1    4/1/2012   Wednesday  Single carriageway      Thirty
# 2   10/1/2012     Tuesday      One way street      Thirty
# 3  18/01/2012   Wednesday  Single carriageway      Thirty
# 4  17/01/2012     Tuesday  Single carriageway      Thirty
#
#   Pedestrian_Human_Control               Pedestrian_Physical_Facilities  \
# ...

# %%
data4.dtypes
# Out:
# Accident_Index                                 object
# Accident_Severity                               int64
# Number_of_Vehicles                              int64
# Number_of_Casualties                            int64
# Date                                           object
# Day_of_Week                                    object
# Road_Type                                      object
# Speed_limit                                    object
# Pedestrian_Human_Control                       object
# Pedestrian_Physical_Facilities                 object
# Light_Conditions                               object
# Weather_Conditions                             object
# Year                                            int64
# Friday                                          uint8
# Monday                                          uint8
# Saturday                                        uint8
# Sunday                                          uint8
# ...

# %%
data4.head()
# Out:
#   Accident_Index  Accident_Severity  Number_of_Vehicles  Number_of_Casualties  \
# 0  201201BS70001                  3                   2                     1
# 1  201201BS70002                  3                   2                     1
# 2  201201BS70003                  3                   2                     1
# 3  201201BS70004                  3                   1                     1
# 4  201201BS70005                  3                   1                     1
#
#          Date Day_of_Week           Road_Type Speed_limit  \
# 0  19/01/2012    Thursday  Single carriageway      Thirty
# 1    4/1/2012   Wednesday  Single carriageway      Thirty
# 2   10/1/2012     Tuesday      One way street      Thirty
# 3  18/01/2012   Wednesday  Single carriageway      Thirty
# 4  17/01/2012     Tuesday  Single carriageway      Thirty
#
#   Pedestrian_Human_Control               Pedestrian_Physical_Facilities  \
# ...

# %%
import statsmodels.api as sm

import matplotlib.pyplot as plt

import seaborn as sns

# %%
y = data4['Number_of_Casualties']

# %%
X = data4[['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Ten','Twenty','Fourty','Fifty','Sixty','Seventy','One way street','Roundabout','Single carriageway','Slip road','Control by other authorised person','Control by school crossing patrol','Central refuge','Footbridge or subway','Pedestrian phase at traffic signal junction','Zebra crossing','non-junction pedestrian crossing','Darkeness: No street lighting','Darkness: Street lighting unknown','Darkness: Street lights present and lit','Darkness: Street lights present but unlit','Fine with high winds','Fog or mist','Other','Raining with high winds','Raining without high winds','Snowing with high winds','Snowing without high winds']]

# %%
X1 = sm.add_constant(X)

# %%
results = sm.OLS(y,X1).fit()

# %%
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ...
# Dep. Variable:     Number_of_Casualties   R-squared:                       0.025
# Model:                              OLS   Adj. R-squared:                  0.025
# Method:                   Least Squares   F-statistic:                     354.8
# Date:                  Sat, 22 Feb 2020   Prob (F-statistic):               0.00
# Time:                          20:11:54   Log-Likelihood:            -5.6179e+05
# No. Observations:                464697   AIC:                         1.124e+06
# Df Residuals:                    464662   BIC:                         1.124e+06
# Df Model:                            34
# Covariance Type:              nonrobust
# ...
#                                                   coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------
# ...

# %%
#Removing unnecessary variables
X2 = data4[['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Twenty','Fourty','Fifty','Sixty','Seventy','One way street','Roundabout','Single carriageway','Slip road','Pedestrian phase at traffic signal junction','Zebra crossing','non-junction pedestrian crossing','Darkeness: No street lighting','Darkness: Street lights present and lit','Fog or mist','Raining without high winds']]
X3 = sm.add_constant(X2)
findings = sm.OLS(y,X3).fit()
findings.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ...
# Dep. Variable:     Number_of_Casualties   R-squared:                       0.025
# Model:                              OLS   Adj. R-squared:                  0.025
# Method:                   Least Squares   F-statistic:                     547.9
# Date:                  Sat, 22 Feb 2020   Prob (F-statistic):               0.00
# Time:                          20:19:33   Log-Likelihood:            -5.6180e+05
# No. Observations:                464697   AIC:                         1.124e+06
# Df Residuals:                    464674   BIC:                         1.124e+06
# Df Model:                            22
# Covariance Type:              nonrobust
# ...
#                                                   coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------------
# ...
